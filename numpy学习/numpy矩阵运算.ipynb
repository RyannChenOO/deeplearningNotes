# %%
import numpy as np

# %% [markdown]
# # 向量点积
#
# ![image.png](attachment:image.png)

# %%
# show common Course 1 example
X = np.array([[1], [2], [3], [4]]) # X_train of dimension (m,n)
X.shape
# Out:
# (4, 1)

# %%
W = np.array([2])
W.shape
# Out:
# (1,)

# %%
res = np.dot(W,X[0]) # W:(1,), X[0]:(1,1)
res
# Out:
# 2
